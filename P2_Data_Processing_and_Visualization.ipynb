# %%
import pandas as pd
#import pandas
import numpy as np
# import numpy
import seaborn as sns
# import seaborn

import matplotlib.pyplot as plt
# import matplotlib

# %%
timeseries_data_info=pd.read_csv("timeseries.csv")
# read csv file

# %%
timeseries_data_info.head()
# first five rows of dataset
# Out:
#          date country state  county  fips  lat  long          locationId  \
# 0  2020-03-02      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 1  2020-03-03      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 2  2020-03-04      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 3  2020-03-05      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
# 4  2020-03-06      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#    actuals.cases  actuals.deaths  ...  metrics.infectionRate  \
# 0            NaN             NaN  ...                    NaN
# 1            NaN             NaN  ...                    NaN
# 2            NaN             NaN  ...                    NaN
# 3            NaN             NaN  ...                    NaN
# 4            2.0             0.0  ...                    NaN
#
#    metrics.infectionRateCI90 metrics.icuHeadroomRatio  \
# 0                        NaN                      NaN
# ...

# %%
timeseries_data_info.info()
# get information of the data types of the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 39 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date                                    501 non-null    object
#  1   country                                 501 non-null    object
#  2   state                                   501 non-null    object
#  3   county                                  0 non-null      float64
#  4   fips                                    501 non-null    int64
#  5   lat                                     0 non-null      float64
#  6   long                                    0 non-null      float64
#  7   locationId                              501 non-null    object
#  8   actuals.cases                           492 non-null    float64
#  9   actuals.deaths                          492 non-null    float64
# ...

# %%
timeseries_data_info.describe()
# Out:
#        county   fips  lat  long  actuals.cases  actuals.deaths  \
# count     0.0  501.0  0.0   0.0   4.920000e+02      492.000000
# mean      NaN   42.0  NaN   NaN   4.610324e+05    12899.796748
# std       NaN    0.0  NaN   NaN   4.402533e+05     9208.187981
# min       NaN   42.0  NaN   NaN   2.000000e+00        0.000000
# 25%       NaN   42.0  NaN   NaN   9.170450e+04     6701.750000
# 50%       NaN   42.0  NaN   NaN   1.923740e+05     8644.500000
# 75%       NaN   42.0  NaN   NaN   9.186368e+05    23644.250000
# max       NaN   42.0  NaN   NaN   1.215735e+06    27675.000000
#
#        actuals.positiveTests  actuals.negativeTests  \
# count           4.960000e+02           4.980000e+02
# mean            4.984688e+05           5.395527e+06
# std             4.503788e+05           4.734033e+06
# min             1.000000e+00           9.000000e+00
# 25%             1.169840e+05           8.947250e+05
# 50%             2.400670e+05           3.855450e+06
# ...

# %%
# the dataset is about convid information of a particular state within USA
# the dataset has 39 columns comprising of information about new cases, deaths and so on

# %%
timeseries_data_info.duplicated().sum()

# get the number of row duplicates in the dataset
# Out:
# 20

# %%
timeseries_data_info["date"] = pd.to_datetime(timeseries_data_info["date"])
# convert datetype object  to datetime

# %%
timeseries_data_info.set_index("date",inplace=True)
# reindex the dataframe using the date

# %%
given_date = timeseries_data_info.loc["2021-06-16"]
# from the question the given date was 2021-06-16.
# use loc to locate data by label. the label is the date given

# %%
given_date
# Out:
#            country state  county  fips  lat  long          locationId  \
# date
# 2021-06-16      US    PA     NaN    42  NaN   NaN  iso1:us#iso2:us-pa
#
#             actuals.cases  actuals.deaths  actuals.positiveTests  ...  \
# date                                                              ...
# 2021-06-16      1214051.0         27582.0              1246387.0  ...
#
#             metrics.infectionRate metrics.infectionRateCI90  \
# date
# 2021-06-16                    0.7                       0.1
#
#             metrics.icuHeadroomRatio  metrics.icuHeadroomDetails  \
# date
# 2021-06-16                       0.1                         NaN
#
#             metrics.icuCapacityRatio  riskLevels.overall  \
# date
# 2021-06-16                      0.73                   1
#
#             metrics.vaccinationsInitiatedRatio  \
# date
# 2021-06-16                               0.611
#
#             metrics.vaccinationsCompletedRatio actuals.newDeaths  \
# date
# ...

# %%
given_date["state"][0]
# get the State in the country
# Out:
# 'PA'

# %%
given_date["actuals.newDeaths"][0]
# get new deaths recording
# Out:
# 16.0

# %%
given_date["actuals.newCases"][0]
# get new cases recording
# Out:
# 279.0

# %%
given_date["actuals.cases"][0]
# get cases recording
# Out:
# 1214051.0

# %%
given_date["actuals.deaths"][0]
# get new deaths recording
# Out:
# 27582.0

# %%
given_date["metrics.vaccinationsInitiatedRatio"][0]
# get population initiated vaccinated ratio
# Out:
# 0.611

# %%
given_date["metrics.vaccinationsCompletedRatio"][0]

# get population completed vaccinated ratio
# Out:
# 0.472

# %%
display = {
    "State": given_date["state"][0],
    "New Death": given_date["actuals.newDeaths"][0],
    "New Cases": given_date["actuals.newCases"][0],
    "Cummulative Cases" : given_date["actuals.cases"][0],
    "Cummulative Death": given_date["actuals.deaths"][0],
    "Initiated Vaccination Ratio": given_date["metrics.vaccinationsInitiatedRatio"][0],
    "Completed Vaccination Ratio":given_date["metrics.vaccinationsCompletedRatio"][0]
}

display
# Out:
# {'State': 'PA',
#  'New Death': 16.0,
#  'New Cases': 279.0,
#  'Cummulative Cases': 1214051.0,
#  'Cummulative Death': 27582.0,
#  'Initiated Vaccination Ratio': 0.611,
#  'Completed Vaccination Ratio': 0.472}

# %%
sns.lineplot(data=data, x="actuals.cases",y='metrics.vaccinationsCompletedRatio')

plt.title("actual Covid cases against vaccinations completed")
#plot graph with actual covid cases on the x axis and vacination completed ratio on the y-axis
# Out:
# Text(0.5, 1.0, 'actual Covid cases against vaccinations completed')

# %%
# as the actual cases increases the vaccination completed ratio is also expected to increase.
